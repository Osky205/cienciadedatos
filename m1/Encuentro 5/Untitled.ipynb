# %%
import pandas

# %%
def funcion(x,y,z):
    return x**2+y-z

# %%
funcion(8,1,3)
# Out:
# 62

# %%
pandas.read_csv('productos.csv', delimiter=';',encoding='latin1')
# Out:
#        producto_id  pais_edicion_id       issn  eissn  pagina_inicial  \
# 0              190                3  2177-6644    NaN             NaN
# 1             3810               21  1389-5575    NaN           428.0
# 2             4637               82  0144-8463    NaN             1.0
# 3             4824               39  1569-4445    NaN           175.0
# 4             5090               21  1040-6182    NaN           165.0
# ...            ...              ...        ...    ...             ...
# 17090       381936               21  0894-0282    NaN             NaN
# 17091       381945                1  1668-5687    NaN             NaN
# 17092       381946                5  0719-3661    NaN           121.0
# 17093       381971                1  2683-6769    NaN             NaN
# 17094       381972                1  1853-5658    NaN           178.0
#
#        pagina_final                               revista volumen numero  \
# ...
